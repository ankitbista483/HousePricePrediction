# %%
import pandas as pd 
import numpy as np

# %%
df = pd.read_csv('/Users/ankitbista/Desktop/practice/HousePricePrediction/dataset.csv')
df_concat = pd.concat([df.head(5),df.tail(5)])
df_concat
# Out:
#         Id  Area  Bedrooms  Bathrooms  Floors  YearBuilt  Location  Condition  \
# 0        1  1360         5          4       3       1970  Downtown  Excellent
# 1        2  4272         5          4       3       1958  Downtown  Excellent
# 2        3  3592         2          2       3       1938  Downtown       Good
# 3        4   966         4          2       2       1902  Suburban       Fair
# 4        5  4926         1          4       2       1975  Downtown       Fair
# 1995  1996  4994         5          4       3       1923  Suburban       Poor
# 1996  1997  3046         5          2       1       2019  Suburban       Poor
# 1997  1998  1062         5          1       2       1903     Rural       Poor
# 1998  1999  4062         3          1       2       1936     Urban  Excellent
# 1999  2000  2989         5          1       3       1903  Suburban       Fair
#
#      Garage   Price
# 0        No  149919
# 1        No  424998
# 2        No  266746
# 3       Yes  244020
# ...

# %%
df['Price']  = df['Price'].astype('Float64')
df['Area'] = df['Area'].astype('Float64')

# %%
df_concat
# Out:
#         Id  Area  Bedrooms  Bathrooms  Floors  YearBuilt  Location  Condition  \
# 0        1  1360         5          4       3       1970  Downtown  Excellent
# 1        2  4272         5          4       3       1958  Downtown  Excellent
# 2        3  3592         2          2       3       1938  Downtown       Good
# 3        4   966         4          2       2       1902  Suburban       Fair
# 4        5  4926         1          4       2       1975  Downtown       Fair
# 1995  1996  4994         5          4       3       1923  Suburban       Poor
# 1996  1997  3046         5          2       1       2019  Suburban       Poor
# 1997  1998  1062         5          1       2       1903     Rural       Poor
# 1998  1999  4062         3          1       2       1936     Urban  Excellent
# 1999  2000  2989         5          1       3       1903  Suburban       Fair
#
#      Garage   Price
# 0        No  149919
# 1        No  424998
# 2        No  266746
# 3       Yes  244020
# ...

# %%
df.describe(include=['object'])
# Out:
#         Location Condition Garage
# count       2000      2000   2000
# unique         4         4      2
# top     Downtown      Fair     No
# freq         558       521   1038

# %%
df.describe()
# Out:
#                 Id         Area     Bedrooms   Bathrooms       Floors  \
# count  2000.000000  2000.000000  2000.000000  2000.00000  2000.000000
# mean   1000.500000  2786.209500     3.003500     2.55250     1.993500
# std     577.494589  1295.146799     1.424606     1.10899     0.809188
# min       1.000000   501.000000     1.000000     1.00000     1.000000
# 25%     500.750000  1653.000000     2.000000     2.00000     1.000000
# 50%    1000.500000  2833.000000     3.000000     3.00000     2.000000
# 75%    1500.250000  3887.500000     4.000000     4.00000     3.000000
# max    2000.000000  4999.000000     5.000000     4.00000     3.000000
#
#          YearBuilt          Price
# count  2000.000000    2000.000000
# mean   1961.446000  537676.855000
# std      35.926695  276428.845719
# min    1900.000000   50005.000000
# 25%    1930.000000  300098.000000
# 50%    1961.000000  539254.000000
# 75%    1993.000000  780086.000000
# max    2023.000000  999656.000000

# %%
df.dtypes
# Out:
# Id            int64
# Area          int64
# Bedrooms      int64
# Bathrooms     int64
# Floors        int64
# YearBuilt     int64
# Location     object
# Condition    object
# Garage       object
# Price         int64
# dtype: object

# %%
df.isnull().sum()
# Out:
# Id           0
# Area         0
# Bedrooms     0
# Bathrooms    0
# Floors       0
# YearBuilt    0
# Location     0
# Condition    0
# Garage       0
# Price        0
# dtype: int64

# %%
duplicates = df.duplicated()
duplicates_count = duplicates.sum()
print(f"The number of duplicates row is {duplicates_count}")
# Out:
# The number of duplicates row is 0

# %%
column = df.columns
column
# Out:
# Index(['Id', 'Area', 'Bedrooms', 'Bathrooms', 'Floors', 'YearBuilt',
#        'Location', 'Condition', 'Garage', 'Price'],
#       dtype='object')

# %%
current_age = 2025
df['HouseAge'] = current_age - df['YearBuilt']

# %%
df.head(5)
# Out:
#    Id    Area  Bedrooms  Bathrooms  Floors  YearBuilt  Location  Condition  \
# 0   1  1360.0         5          4       3       1970  Downtown  Excellent
# 1   2  4272.0         5          4       3       1958  Downtown  Excellent
# 2   3  3592.0         2          2       3       1938  Downtown       Good
# 3   4   966.0         4          2       2       1902  Suburban       Fair
# 4   5  4926.0         1          4       2       1975  Downtown       Fair
#
#   Garage     Price  HouseAge
# 0     No  149919.0        55
# 1     No  424998.0        67
# 2     No  266746.0        87
# 3    Yes  244020.0       123
# 4    Yes  636056.0        50

# %%
df['Location'].unique()
# Out:
# array(['Downtown', 'Suburban', 'Urban', 'Rural'], dtype=object)

# %%
df['Condition'].unique()
# Out:
# array(['Excellent', 'Good', 'Fair', 'Poor'], dtype=object)

# %%
df.to_csv('/Users/ankitbista/Desktop/practice/HousePricePrediction/dataset.csv', index=False)
